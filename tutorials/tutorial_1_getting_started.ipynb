# %% [markdown]
# # Tutorial 1: Getting started
# This tutorial shows

# %% [markdown]
# ## 1. Instructions on logging into VM on localhost with port forwarding

# %% [markdown]
# ## 2. Create API account
# * Provide your full name, email address, and upi to the CTT group.<br>
# * The system administrator will add the you as a user.

# %% [markdown]
# ## 3. Getting API key
# * Navigate to the [GEN3 website](https://gen3.abi-ctt-ctp.cloud.edu.au/identity).

# %%
# This code is added only for the purpose of displaying the images.
from IPython.display import Image
Image(filename='../tutorials/images/GEN3_website.png')

# %% [markdown]
# * Login using your UoA credentials. The Login button can be found at the top right corner of the GEN3 website. Or you can click on the 'Login from Google' button in the middle of the homepage.

# %% [markdown]
# * Click on the 'Create API key' button.

# %%
Image(filename='../tutorials/images/GEN3_website_create_API_key.png')

# %% [markdown]
# * Once the API key is generated, you will see an option to 'Download' it. Click on this option, and the API key will be saved as "credentials.json" to your downloads folder.

# %%
Image(filename='../tutorials/images/GEN3_website_create_API_key_download.png')

# %% [markdown]
# ## 4. Creating a python environment for accessing the Digital Twin Platform
# ### Virtual environment (Recommended)
# * Create a virtual environment
# ```python
#     python3 -m venv venv/
# ```
#
# * Activate the virtual environment
# ```python
#     source venv/bin/activate
# ```
#
# * Install the dependencies (TBU)
# ```python
#     pip install pypi-install
# ```
# ### Not using a virtual environment (Not recommended)
